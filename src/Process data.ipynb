# %%
import docx
import re
import nltk.data

def getText(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

def cleaner(text):
    text=re.sub(r'\n|[,\"\(\)~!*\'\@\&\^#“”:;_.]+','',text)
    text=re.sub(r'[\/]+',' ',text)
    text=text.strip()
    return text

# %%
import re
alphabets= "([A-Za-z])"
prefixes = "(Mr|St|Mrs|Ms|Dr)[.]"
suffixes = "(Inc|Ltd|Jr|Sr|Co)"
starters = "(Mr|Mrs|Ms|Dr|He\s|She\s|It\s|They\s|Their\s|Our\s|We\s|But\s|However\s|That\s|This\s|Wherever)"
acronyms = "([A-Z][.][A-Z][.](?:[A-Z][.])?)"
websites = "[.](com|net|org|io|gov)"

def split_into_sentences(text):
    text = " " + text + "  "
    text = text.replace("\n"," ")
    text = re.sub(prefixes,"\\1<prd>",text)
    text = re.sub(websites,"<prd>\\1",text)
    if "Ph.D" in text: text = text.replace("Ph.D.","Ph<prd>D<prd>")
    text = re.sub("\s" + alphabets + "[.] "," \\1<prd> ",text)
    text = re.sub(acronyms+" "+starters,"\\1<stop> \\2",text)
    text = re.sub(alphabets + "[.]" + alphabets + "[.]" + alphabets + "[.]","\\1<prd>\\2<prd>\\3<prd>",text)
    text = re.sub(alphabets + "[.]" + alphabets + "[.]","\\1<prd>\\2<prd>",text)
    text = re.sub(" "+suffixes+"[.] "+starters," \\1<stop> \\2",text)
    text = re.sub(" "+suffixes+"[.]"," \\1<prd>",text)
    text = re.sub(" " + alphabets + "[.]"," \\1<prd>",text)
    if "”" in text: text = text.replace(".”","”.")
    if "\"" in text: text = text.replace(".\"","\".")
    if "!" in text: text = text.replace("!\"","\"!")
    if "?" in text: text = text.replace("?\"","\"?")
    text = text.replace(".",".<stop>")
    text = text.replace("?","?<stop>")
    text = text.replace("!","!<stop>")
    text = text.replace("<prd>",".")
    sentences = text.split("<stop>")
    sentences = sentences[:-1]
    sentences = [s.strip() for s in sentences]
    return sentences

# %%
data = getText('../data/contract_1/Aquinas/Aquinas Independent Contractor Agreement - Itlize Global LLC..docx')
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
tokenizer.tokenize(data)
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# <ipython-input-45-6b6fa1a8eea6> in <module>
# ----> 1 getText('../data/contract_1/Aquinas/Aquinas Independent Contractor Agreement - Itlize Global LLC..docx')
#
# <ipython-input-42-c448a1547ab2> in getText(filename)
#       4
#       5 def getText(filename):
# ----> 6     doc = docx.Document(filename)
#       7     fullText = []
#       8     for para in doc.paragraphs:
#
# ~/.conda/envs/p35/lib/python3.5/site-packages/docx/api.py in Document(docx)
#      23     """
#      24     docx = _default_docx_path() if docx is None else docx
# ---> 25     document_part = Package.open(docx).main_document_part
#      26     if document_part.content_type != CT.WML_DOCUMENT_MAIN:
#      27         tmpl = "file '%s' is not a Word file, content type is '%s'"
#
# ...

# %%
sentences = [x.split('\n\n') for x in tokenize.sent_tokenize(getText('../data/contract_1/Aquinas/Aquinas Independent Contractor Agreement - Itlize Global LLC..docx'))]
result = []
for i in sentences:
    for j in i:
        result.append(j)
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-9aa3e8f3430c> in <module>
# ----> 1 sentences = [x.split('\n\n',':') for x in tokenize.sent_tokenize(getText('../data/contract_1/Aquinas/Aquinas Independent Contractor Agreement - Itlize Global LLC..docx'))]
#       2 result = []
#       3 for i in sentences:
#       4     for j in i:
#       5         result.append(j)
#
# NameError: name 'tokenize' is not defined

# %%
sentences = str(split_into_sentences(x) for x in sentences)

# %%
sentences
# Out:
# '<generator object <genexpr> at 0x7f6296c476d0>'

# %%
final = []
for i in result:
    final.append(cleaner(i).lower())

# %%
result
# Out:
# ['',
#  'independent  contractor agreement',
#  'this independent contractor agreement agreement is made this 9th day of october 2018 between aquinas consulting llc a connecticut corporation hereafteraquinas and itlize global llc a new jersey corporation hereafter contractor wherein the parties agree as follows',
#  'recitals',
#  'aquinas is in the business of providing computer programmers systems analysts and other information technology personnel on a contract contract-to-hire or direct-hire basis to its clients clients',
#  'contractor is engaged actively in the business of providing information technology services',
#  'in consideration of the mutual promises set forth in this agreement aquinas and contractor agree as follows',
#  'description of work',
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_lg")


data = getText('../data/contract_1/Aquinas/Aquinas Independent Contractor Agreement - Itlize Global LLC..docx')
text = data
tokens = nlp(text)

for sent in tokens.sents:
    print(sent.string.strip())
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# <ipython-input-51-cbd294f4137a> in <module>
#       3
#       4
# ----> 5 data = getText('../data/contract_1/Aquinas/Aquinas Independent Contractor Agreement - Itlize Global LLC..docx')
#       6 text = data
#       7 tokens = nlp(text)
#
# <ipython-input-46-7278ff502b14> in getText(filename)
#       4
#       5 def getText(filename):
# ----> 6     doc = docx.Document(filename)
#       7     fullText = []
#       8     for para in doc.paragraphs:
#
# ~/.conda/envs/p35/lib/python3.5/site-packages/docx/api.py in Document(docx)
#      23     """
#      24     docx = _default_docx_path() if docx is None else docx
# ---> 25     document_part = Package.open(docx).main_document_part
#      26     if document_part.content_type != CT.WML_DOCUMENT_MAIN:
#      27         tmpl = "file '%s' is not a Word file, content type is '%s'"
#
# ...

# %%
# !python -m spacy download en
# Out:
# /home/itlize/anaconda3/bin/python: No module named spacy

# %%
ls /home/itlize/anaconda3/bin
# Out:
# 2to3@                                ktutil*
# 2to3-3.7*                            kvno*
# activate*                            launch_instance*
# anaconda*                            lconvert*
# anaconda-navigator*                  libpng16-config*
# anaconda-project*                    libpng-config@
# asadmin*                             libtool*
# assistant*                           libtoolize*
# binstar*                             linguist*
# bokeh*                               list_instances*
# bsdcat*                              lrelease*
# bsdcpio*                             lss3*
# bsdtar*                              lupdate*
# bundle_image*                        lz4*
# bunzip2*                             lz4c@
# bzcat*                               lz4cat@
# bzcmp@                               lzcat@
# bzdiff*                              lzcmp@
# bzegrep@                             lzdiff@
# bzfgrep@                             lzegrep@
# ...

# %%
import docx
import re
import nltk.data

def getText(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)
