# %%
import pickle
import pandas as pd

# %%
with open('../data/contract/raw_df.pkl','rb') as f:
    df=pickle.load(f)

# %%
df[['batch_idx','content','label']].head(100)
# Out:
#     batch_idx                                            content  \
# 0           0                                      Retainer-Term
# 0           0  This Agreement is made with consultant as an i...
# 1           0   Consultant agrees to be liable for all applic...
# 2           0   Novius hereby retains Consultant and Consulta...
# 0           0                                  Client Assignment
# 0           1                                      Retainer-Term
# 0           1  This Agreement is made with consultant as an i...
# 1           1   Consultant agrees to be liable for all applic...
# 2           1   Novius hereby retains Consultant and Consulta...
# 0           1                                  Client Assignment
# 0           2  Work orders may be extended by Novius beyond t...
# 1           2   Each and every extension period  shall be ent...
# 0           2  Consultant agrees to be bound by the terms and...
# ...
